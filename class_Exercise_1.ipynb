# %% [markdown]
# <a href="https://colab.research.google.com/github/vidhya200617-art/class_Example/blob/main/class_Exercise_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Name=input("Enter the name:")
balance=float(input("Enter the balance:"))
print("1.Deposit","2.withdraw","3.Balance")
choice=int(input("Enter your choice(1/2/3)"))
if(choice==1):
  amount=int(input("Enter your amount to deposit:"))
  if amount>0:
    balance=balance+amount
    print(balance)
  else:
    print("Invalid amount")
elif(choice==2):
  amount=int(input("Enter amount for withdraw:"))
  if amount<balance:
    balance=balance-withdraw
    print("Balance amount",balance)
  else:
    print("invalid amount")
elif(choice==3):
  print("Account name",Name)
  print("Balance",balance)
else:
  print("Invalid choice!!")
# Out:
# Enter the name:aa
# Enter the balance:200
# 1.Deposit 2.withdraw 3.Balance
# Enter your choice(1/2/3)1
# Enter your amount to deposit:50000
# 50200.0

# %%
 user={}
 def register():
    print("Register")
    username=input("Enter username:")
    if username in user:
        print("Username already exists..")
        return
    password=input("Enter password:")
    user[username]=password
    print("Registration successful")
def login():
    print("Login")
    username=input("Enter username:")
    password=input("Enter password:")
    if username in user and user[username]==password:
        print("Login successful")
    else:
        print("Invalid")
while True:
    print("1.Register","2.Login","3.Exit")
    choice=input("Enter your choice (1/2/3):")

    if choice=="1":
        register()
    elif choice=="2":
        login()
    elif choice=="3":
        print("Existing")
        break
    else:
        print("Invalid choice")
# Out:
# 1.Register 2.Login 3.Exit
# Enter your choice (1/2/3):1
# Register
# Enter username:lily
# Enter password:12345
# Registration successful
# 1.Register 2.Login 3.Exit
